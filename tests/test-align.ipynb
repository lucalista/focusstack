# %%
# %run -i "test_0030_align.py"
# Out:
# [INF] align-jpg: begin run
# [INF] align-jpg: : 6 files in folder: ./input/img-jpg
# [INF] align-jpg: focus stacking
# align-jpg:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] align-jpg: step 6/6: process file: 0000.jpg, reference: 0001.jpg: write output image
# [INF] align-jpg: elapsed time: 00:00:05.89s
# [INF] align-jpg: completed
# [INF] job: elapsed time: 00:00:05.89s
# [INF] job: completed
# [INF] align-tif: begin run
# [INF] align-tif: : 6 files in folder: ./input/img-tif
# [INF] align-tif: focus stacking
# align-tif:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] align-tif: step 6/6: process file: 0000.tif, reference: 0001.tif: write output image
# [INF] align-tif: elapsed time: 00:00:05.64s
# [INF] align-tif: completed
# [INF] job: elapsed time: 00:00:05.64s
# [INF] job: completed
