# %%
# %run -i "test_0030_align.py"
# Out:
# [WAR] align-jpg: : output directory output/img-jpg-align not empty, files may be overwritten or merged with existing ones.
# [INF] align-jpg: begin run
# [INF] align-jpg: : 6 files in folder: input/img-jpg
# [INF] align-jpg: focus stacking
# align-jpg:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] align-jpg: step 1/6: process file: 0000.jpg, reference: 0003.jpg: write output image
# [INF] align-jpg: step 2/6: process file: 0001.jpg, reference: 0003.jpg: write output image
# [INF] align-jpg: step 3/6: process file: 0002.jpg, reference: 0003.jpg: write output image
# [INF] align-jpg: step 4/6: process file: 0003.jpg, reference: 0003.jpg: write output image
# [INF] align-jpg: step 5/6: process file: 0004.jpg, reference: 0003.jpg: write output image
# [INF] align-jpg: step 6/6: process file: 0005.jpg, reference: 0003.jpg: write output image
# [INF] align-jpg: elapsed time: 00:00:05.09s
# [INF] align-jpg: completed
# [INF] job: elapsed time: 00:00:05.09s
# [INF] job: completed
# ...
