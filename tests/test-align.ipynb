# %%
import sys
sys.path.append('../')
from focus_stack import *

# %%
job = StackJob("job", "./", input_path="img-jpg")
job.add_action(Actions("img-jpg-align", actions=[AlignFrames(plot_matches=True)]))
job.run()
# Out:
# [INF] img-jpg-align: 6 files in folder: ./img-jpg-align
# img-jpg-align:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align: step 2/6: process file: 0004.jpg, reference: 0003.jpg : matches: 164
# [INF] img-jpg-align: step 3/6: process file: 0005.jpg, reference: 0004.jpg : matches: 73s
# [INF] img-jpg-align: step 4/6: process file: 0002.jpg, reference: 0003.jpg : matches: 150
# [INF] img-jpg-align: step 5/6: process file: 0001.jpg, reference: 0002.jpg : matches: 137
# [INF] img-jpg-align: step 6/6: process file: 0000.jpg, reference: 0001.jpg : matches: 91s
# [INF] img-jpg-align: step 6/6: process file: 0000.jpg, reference: 0001.jpg : write image
# [INF] img-jpg-align: elapsed time: 00:00:05.38s
# [INF] img-jpg-align: completed
# [INF] job: elapsed time: 00:00:05.38s
# [INF] job: completed

# %%
job = StackJob("job", "./", input_path="img-tif")
job.add_action(Actions("img-tif-align", actions=[AlignFrames()]))
job.run()
# Out:
# [INF] img-tif-align: 6 files in folder: ./img-tif-align
# img-tif-align:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-tif-align: step 6/6: process file: 0000.tif, reference: 0001.tif : write image
# [INF] img-tif-align: elapsed time: 00:00:02.43s
# [INF] img-tif-align: completed
# [INF] job: elapsed time: 00:00:02.43s
# [INF] job: completed
