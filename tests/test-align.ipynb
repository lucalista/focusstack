# %%
# %run -i "test_0030_align.py"
# Out:
# [INF] img-jpg-align: begin run
# [INF] img-jpg-align: : 6 files in folder: ./img-jpg
# img-jpg-align:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align: step 6/6: process file: 0000.jpg, reference: 0001.jpg: write output image
# [INF] img-jpg-align: elapsed time: 00:00:04.87s
# [INF] img-jpg-align: completed
# [INF] job: elapsed time: 00:00:04.87s
# [INF] job: completed
# [INF] img-tif-align: begin run
# [INF] img-tif-align: : 6 files in folder: ./img-tif
# img-tif-align:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-tif-align: step 6/6: process file: 0000.tif, reference: 0001.tif: write output image
# [INF] img-tif-align: elapsed time: 00:00:02.31s
# [INF] img-tif-align: completed
# [INF] job: elapsed time: 00:00:02.31s
# [INF] job: completed
