# %%
# %run -i "test_0030_align.py"
# Out:
# None
# img-jpg
# [INF] img-jpg-align: 6 files in folder: ./img-jpg
# img-jpg-align:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align: step 2/6: process file: 0004.jpg, reference: 0003.jpg : matches: 206.
# [INF] img-jpg-align: step 3/6: process file: 0005.jpg, reference: 0004.jpg : matches: 101.
# [INF] img-jpg-align: step 4/6: process file: 0002.jpg, reference: 0003.jpg : matches: 210.
# [INF] img-jpg-align: step 5/6: process file: 0001.jpg, reference: 0002.jpg : matches: 198.
# [INF] img-jpg-align: step 6/6: process file: 0000.jpg, reference: 0001.jpg : matches: 143.
# [INF] img-jpg-align: step 6/6: process file: 0000.jpg, reference: 0001.jpg : write image
# [INF] img-jpg-align: elapsed time: 00:00:06.86s
# [INF] img-jpg-align: completed
# [INF] job: elapsed time: 00:00:06.86s
# [INF] job: completed
# None
# img-tif
# [INF] img-tif-align: 6 files in folder: ./img-tif
# img-tif-align:   0%|          | 0/6 [00:00<?, ?it/s]
# ...
