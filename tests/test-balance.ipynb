# %%
import sys
sys.path.append('../')
from focus_stack import *

# %%
job = StackJob("job", "./", input_path="img-tif")
job.add_action(Actions("img-tif-balance-rgb-match", actions=[BalanceFrames(channel=RGB, corr_map=MATCH_HIST, plot_histograms=True)]))
job.run()
# Out:
# [INF] img-tif-balance-rgb-match: 6 files in folder: ./img-tif-balance-rgb-match
# img-tif-balance-rgb-match:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-tif-balance-rgb-match: step 2/6: process file: 0004.tif, reference: 0003.tif : balance image
# [INF] img-tif-balance-rgb-match: step 3/6: process file: 0005.tif, reference: 0004.tif : balance image
# [INF] img-tif-balance-rgb-match: step 4/6: process file: 0002.tif, reference: 0003.tif : balance image
# [INF] img-tif-balance-rgb-match: step 5/6: process file: 0001.tif, reference: 0002.tif : balance image
# [INF] img-tif-balance-rgb-match: step 6/6: process file: 0000.tif, reference: 0001.tif : balance image
# [INF] img-tif-balance-rgb-match:
# [INF] img-tif-balance-rgb-match: elapsed time: 00:00:12.23s
# [INF] img-tif-balance-rgb-match: completed
# [INF] job: elapsed time: 00:00:12.23s
# [INF] job: completed

# %%
job = StackJob("job", "./", input_path="img-jpg")
job.add_action(Actions("img-jpg-balance-lumi", actions=[BalanceFrames(channel=LUMI, corr_map=LINEAR, plot_histograms=True)]))
job.run()
# Out:
# [INF] img-jpg-balance-lumi: 6 files in folder: ./img-jpg-balance-lumi
# img-jpg-balance-lumi:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-balance-lumi: step 2/6: process file: 0004.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-lumi: step 3/6: process file: 0005.jpg, reference: 0004.jpg : balance image
# [INF] img-jpg-balance-lumi: step 4/6: process file: 0002.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-lumi: step 5/6: process file: 0001.jpg, reference: 0002.jpg : balance image
# [INF] img-jpg-balance-lumi: step 6/6: process file: 0000.jpg, reference: 0001.jpg : balance image
# [INF] img-jpg-balance-lumi:
# [INF] img-jpg-balance-lumi: elapsed time: 00:00:01.42s
# [INF] img-jpg-balance-lumi: completed
# [INF] job: elapsed time: 00:00:01.42s
# [INF] job: completed

# %%
job = StackJob("job", "./", input_path="img-tif")
job.add_action(Actions("img-tif-balance-lumi", actions=[BalanceFrames(channel=LUMI, corr_map=GAMMA, plot_histograms=True)]))
job.run()
# Out:
# [INF] img-tif-balance-lumi: 6 files in folder: ./img-tif-balance-lumi
# img-tif-balance-lumi:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-tif-balance-lumi: step 2/6: process file: 0004.tif, reference: 0003.tif : balance image
# [INF] img-tif-balance-lumi: step 3/6: process file: 0005.tif, reference: 0004.tif : balance image
# [INF] img-tif-balance-lumi: step 4/6: process file: 0002.tif, reference: 0003.tif : balance image
# [INF] img-tif-balance-lumi: step 5/6: process file: 0001.tif, reference: 0002.tif : balance image
# [INF] img-tif-balance-lumi: step 6/6: process file: 0000.tif, reference: 0001.tif : balance image
# [INF] img-tif-balance-lumi:
# [INF] img-tif-balance-lumi: elapsed time: 00:00:02.49s
# [INF] img-tif-balance-lumi: completed
# [INF] job: elapsed time: 00:00:02.49s
# [INF] job: completed

# %%
job = StackJob("job", "./", input_path="img-jpg")
job.add_action(Actions("img-jpg-balance-rgb", actions=[BalanceFrames(channel=RGB, corr_map=LINEAR, plot_histograms=True)]))
job.run()
# Out:
# [INF] img-jpg-balance-rgb: 6 files in folder: ./img-jpg-balance-rgb
# img-jpg-balance-rgb:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-balance-rgb: step 2/6: process file: 0004.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-rgb: step 3/6: process file: 0005.jpg, reference: 0004.jpg : balance image
# [INF] img-jpg-balance-rgb: step 4/6: process file: 0002.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-rgb: step 5/6: process file: 0001.jpg, reference: 0002.jpg : balance image
# [INF] img-jpg-balance-rgb: step 6/6: process file: 0000.jpg, reference: 0001.jpg : balance image
# [INF] img-jpg-balance-rgb:
# [INF] img-jpg-balance-rgb: elapsed time: 00:00:01.79s
# [INF] img-jpg-balance-rgb: completed
# [INF] job: elapsed time: 00:00:01.79s
# [INF] job: completed

# %%
job = StackJob("job", "./", input_path="img-jpg")
job.add_action(Actions("img-jpg-balance-sv", actions=[BalanceFrames(channel=HSV, corr_map=LINEAR, plot_histograms=True)]))
job.run()
# Out:
# [INF] img-jpg-balance-sv: 6 files in folder: ./img-jpg-balance-sv
# img-jpg-balance-sv:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-balance-sv: step 2/6: process file: 0004.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-sv: step 3/6: process file: 0005.jpg, reference: 0004.jpg : balance image
# [INF] img-jpg-balance-sv: step 4/6: process file: 0002.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-sv: step 5/6: process file: 0001.jpg, reference: 0002.jpg : balance image
# [INF] img-jpg-balance-sv: step 6/6: process file: 0000.jpg, reference: 0001.jpg : balance image
# [INF] img-jpg-balance-sv:
# [INF] img-jpg-balance-sv: elapsed time: 00:00:01.86s
# [INF] img-jpg-balance-sv: completed
# [INF] job: elapsed time: 00:00:01.87s
# [INF] job: completed

# %%
job = StackJob("job", "./", input_path="img-jpg")
job.add_action(Actions("img-jpg-balance-ls", actions=[BalanceFrames(channel=HLS, corr_map=GAMMA, plot_histograms=True)]))
job.run()
# Out:
# [INF] img-jpg-balance-ls: 6 files in folder: ./img-jpg-balance-ls
# img-jpg-balance-ls:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-balance-ls: step 2/6: process file: 0004.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-ls: step 3/6: process file: 0005.jpg, reference: 0004.jpg : balance image
# [INF] img-jpg-balance-ls: step 4/6: process file: 0002.jpg, reference: 0003.jpg : balance image
# [INF] img-jpg-balance-ls: step 5/6: process file: 0001.jpg, reference: 0002.jpg : balance image
# [INF] img-jpg-balance-ls: step 6/6: process file: 0000.jpg, reference: 0001.jpg : balance image
# [INF] img-jpg-balance-ls:
# [INF] img-jpg-balance-ls: elapsed time: 00:00:01.89s
# [INF] img-jpg-balance-ls: completed
# [INF] job: elapsed time: 00:00:01.89s
# [INF] job: completed
