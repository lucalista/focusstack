# %%
# %run -i "test_0040_balance.py"
# Out:
# [INF] img-tif-balance-rgb-match: begin run
# [INF] img-tif-balance-rgb-match: : 6 files in folder: ./img-tif
# img-tif-balance-rgb-match:   0%|          | 0/6 [00:00<?, ?it/s]
# img-tif-balance-rgb-match: step 1/6: process file: 0003.tif, reference: 0003.tif
# img-tif-balance-rgb-match: step 1/6: process file: 0003.tif, reference: 0003.tif: read image
# img-tif-balance-rgb-match: step 1/6: process file: 0003.tif, reference: 0003.tif: write image
# img-tif-balance-rgb-match: step 2/6: process file: 0004.tif, reference: 0003.tif
# img-tif-balance-rgb-match: step 2/6: process file: 0004.tif, reference: 0003.tif: read image
# img-tif-balance-rgb-match: step 2/6: process file: 0004.tif, reference: 0003.tif: balance image
# img-tif-balance-rgb-match: step 2/6: process file: 0004.tif, reference: 0003.tif: write image
# img-tif-balance-rgb-match: step 3/6: process file: 0005.tif, reference: 0004.tif
# ...
