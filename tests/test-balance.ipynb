# %%
# %run -i "test_0040_balance.py"
# Out:
# [WAR] balance: : output directory output/img-tif-balance-rgb-match not empty, files may be overwritten or merged with existing ones.
# [INF] balance: begin run
# [INF] balance: : 6 files in folder: input/img-tif
# [INF] balance: focus stacking
# balance:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] balance: step 1/6: process file: 0000.tif, reference: 0003.tif: balance image
# [INF] balance: step 1/6: process file: 0000.tif, reference: 0003.tif: write output image
# [INF] balance: step 2/6: process file: 0001.tif, reference: 0003.tif: balance image
# [INF] balance: step 2/6: process file: 0001.tif, reference: 0003.tif: write output image
# [INF] balance: step 3/6: process file: 0002.tif, reference: 0003.tif: balance image
# [INF] balance: step 3/6: process file: 0002.tif, reference: 0003.tif: write output image
# [INF] balance: step 4/6: process file: 0003.tif, reference: 0003.tif: write output image
# ...
