# %%
# %run -i "test_0050_align_balance.py"
# Out:
# None
# img-jpg
# [INF] img-jpg-align-balance-ls: 6 files in folder: ./img-jpg
# img-jpg-align-balance-ls:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align-balance-ls: step 6/6: process file: 0000.jpg, reference: 0001.jpg : write image
# [INF] img-jpg-align-balance-ls:
# [INF] img-jpg-align-balance-ls: elapsed time: 00:00:03.98s
# [INF] img-jpg-align-balance-ls: completed
# [INF] job: elapsed time: 00:00:03.98s
# [INF] job: completed
# None
# img-jpg
# [INF] img-jpg-align-balance-sv: 6 files in folder: ./img-jpg
# img-jpg-align-balance-sv:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align-balance-sv: step 6/6: process file: 0000.jpg, reference: 0001.jpg : write image
# [INF] img-jpg-align-balance-sv:
# [INF] img-jpg-align-balance-sv: elapsed time: 00:00:03.94s
# [INF] img-jpg-align-balance-sv: completed
# [INF] job: elapsed time: 00:00:03.94s
# [INF] job: completed
# None
# img-jpg
# [INF] img-jpg-align-balance-rgb: 6 files in folder: ./img-jpg
# ...
