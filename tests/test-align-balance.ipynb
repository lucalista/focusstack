# %%
# %run -i "test_0050_align_balance.py"
# Out:
# [INF] img-jpg-align-balance-ls: begin run
# [INF] img-jpg-align-balance-ls: : 6 files in folder: ./img-jpg
# img-jpg-align-balance-ls:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align-balance-ls: step 6/6: process file: 0000.jpg, reference: 0001.jpg: write output image
# [INF] img-jpg-align-balance-ls:
# [INF] img-jpg-align-balance-ls: elapsed time: 00:00:02.73s
# [INF] img-jpg-align-balance-ls: completed
# [INF] job: elapsed time: 00:00:02.74s
# [INF] job: completed
# [INF] img-jpg-align-balance-sv: begin run
# [INF] img-jpg-align-balance-sv: : 6 files in folder: ./img-jpg
# img-jpg-align-balance-sv:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-jpg-align-balance-sv: step 6/6: process file: 0000.jpg, reference: 0001.jpg: write output image
# [INF] img-jpg-align-balance-sv:
# [INF] img-jpg-align-balance-sv: elapsed time: 00:00:02.53s
# [INF] img-jpg-align-balance-sv: completed
# [INF] job: elapsed time: 00:00:02.53s
# [INF] job: completed
# ...
