# %%
# %run -i "test_0090_vignetting.py"
# Out:
# [INF] img-vignetting: begin run
# [INF] img-vignetting: : 4 files in folder: ./img-vignetted
# [INF] img-vignetting: focus stacking
# img-vignetting:   0%|          | 0/4 [00:00<?, ?it/s]
# Fit parameters: i0=166.22, k=0.01, r0=930.21step 1/4: process file: vig-0002.jpg, reference: vig-0002.jpg: read imput image
# Fit parameters: i0=164.14, k=0.01, r0=958.24step 2/4: process file: vig-0003.jpg, reference: vig-0002.jpg: read imput image
# Fit parameters: i0=174.51, k=0.01, r0=889.25step 3/4: process file: vig-0001.jpg, reference: vig-0002.jpg: read imput image
# Fit parameters: i0=169.41, k=0.01, r0=909.73step 4/4: process file: vig-0000.jpg, reference: vig-0001.jpg: read imput image
# [INF] img-vignetting: elapsed time: 00:00:03.61s                              g: write output image
# [INF] img-vignetting: completed
# [INF] job: elapsed time: 00:00:03.61s
# [INF] job: completed
