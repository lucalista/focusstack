# %%
# %run -i "test_0090_vignetting.py"
# Out:
# [INF] img-vignetting: begin run
# [INF] img-vignetting: : 4 files in folder: ./img-vignetted
# [INF] img-vignetting: focus stacking
# img-vignetting:   0%|          | 0/4 [00:00<?, ?it/s]
# [INF] img-vignetting: step 1/4: process file: vig-0002.jpg, reference: vig-0002.jpg: read imput image
# 255 5
# [INF] img-vignetting: step 2/4: process file: vig-0003.jpg, reference: vig-0002.jpg: read imput image
# 255 10
# [INF] img-vignetting: step 3/4: process file: vig-0001.jpg, reference: vig-0002.jpg: read imput image
# 255 1
# [INF] img-vignetting: step 4/4: process file: vig-0000.jpg, reference: vig-0001.jpg: read imput image
# 255 2
# [INF] img-vignetting: step 4/4: process file: vig-0000.jpg, reference: vig-0001.jpg: write output image
# [INF] img-vignetting: elapsed time: 00:00:01.77s
# [INF] img-vignetting: completed
# [INF] job: elapsed time: 00:00:01.77s
# [INF] job: completed
